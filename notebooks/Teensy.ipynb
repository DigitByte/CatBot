# %% [markdown]
# CatBot Lab Context: This notebook supports the CatBot course and focuses on Tutorial to install drivers in Teensy.
#
# # Tutorial to install drivers in Teensy

# %% [markdown]
# This tutorial is based on the tutorial of ros_teensy: https://github.com/mcgill-robotics/ros-teensy
#
# Open a terminal (Ctrl + T) and install arm compiler toolchain from the GNU tools:
#
# __sudo apt-get install gcc-arm-none-eabi__
#
# ________________
# You will need the Arduino and Teensyduino libraries. You can find all the information here:
# https://www.pjrc.com/teensy/teensyduino.html

# %% [markdown]
# You will need to set an environment variable to point to the where you installed the Arduino libraries. So add a line like the following to your .bashrc file or any other file you source in every terminal
#
# __export arduino_location=the_location__
